# %%
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors

df1 = pd.read_csv("1045.txt", delimiter = "\t")

# %%
df1
# Out:
#        MeSH Symptom Term                       MeSH Disease Term  \
# 0       Aging, Premature  Respiratory Syncytial Virus Infections
# 1       Aging, Premature             Orthomyxoviridae Infections
# 2       Aging, Premature                          HIV Infections
# 3       Aging, Premature      Acquired Immunodeficiency Syndrome
# 4       Aging, Premature                        Breast Neoplasms
# ...                  ...                                     ...
# 147973         Hirsutism                    Tobacco Use Disorder
# 147974         Hirsutism                        Radius Fractures
# 147975         Hirsutism                                   Burns
# 147976         Hirsutism                        Colles' Fracture
# 147977         Hirsutism                      Radiation Injuries
#
#         PubMed occurrence  TFIDF score
# 0                       1     3.464551
# 1                       1     3.464551
# 2                       3    10.393654
# 3                       3    10.393654
# 4                       1     3.464551
# ...                   ...          ...
# 147973                  1     2.483722
# 147974                  1     2.483722
# 147975                  1     2.483722
# 147976                  1     2.483722
# 147977                  1     2.483722
#
# [147978 rows x 4 columns]

# %%
df1.drop('PubMed occurrence',axis=1,inplace=True)
df1
# Out:
#        MeSH Symptom Term                       MeSH Disease Term  TFIDF score
# 0       Aging, Premature  Respiratory Syncytial Virus Infections     3.464551
# 1       Aging, Premature             Orthomyxoviridae Infections     3.464551
# 2       Aging, Premature                          HIV Infections    10.393654
# 3       Aging, Premature      Acquired Immunodeficiency Syndrome    10.393654
# 4       Aging, Premature                        Breast Neoplasms     3.464551
# ...                  ...                                     ...          ...
# 147973         Hirsutism                    Tobacco Use Disorder     2.483722
# 147974         Hirsutism                        Radius Fractures     2.483722
# 147975         Hirsutism                                   Burns     2.483722
# 147976         Hirsutism                        Colles' Fracture     2.483722
# 147977         Hirsutism                      Radiation Injuries     2.483722
#
# [147978 rows x 3 columns]

# %%
combine_product_review = df1.dropna(axis = 0, subset = ['MeSH Symptom Term'])
product_reviewCount = (combine_product_review.
     groupby(by = ['MeSH Symptom Term'])['TFIDF score'].
     count().
     reset_index().
     rename(columns = {'TFIDF score': 'totalTFIDFscore'})
     [['MeSH Symptom Term','totalTFIDFscore']]
    )
product_reviewCount.head()
# Out:
#          MeSH Symptom Term  totalTFIDFscore
# 0           Abdomen, Acute             1002
# 1           Abdominal Pain             1599
# 2  Acute Coronary Syndrome              314
# 3                Aerophagy               72
# 4                  Ageusia              117

# %%
review_with_totalReviewCount  = combine_product_review.merge(product_reviewCount, left_on = 'MeSH Symptom Term', right_on = 'MeSH Symptom Term', how = 'left')
review_with_totalReviewCount.head()
# Out:
#   MeSH Symptom Term                       MeSH Disease Term  TFIDF score  \
# 0  Aging, Premature  Respiratory Syncytial Virus Infections     3.464551
# 1  Aging, Premature             Orthomyxoviridae Infections     3.464551
# 2  Aging, Premature                          HIV Infections    10.393654
# 3  Aging, Premature      Acquired Immunodeficiency Syndrome    10.393654
# 4  Aging, Premature                        Breast Neoplasms     3.464551
#
#    totalTFIDFscore
# 0              132
# 1              132
# 2              132
# 3              132
# 4              132

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print(product_reviewCount['totalTFIDFscore'].describe())
# Out:
# count    322.000
# mean     459.559
# std      456.715
# min        1.000
# 25%      123.250
# 50%      310.000
# 75%      682.500
# max     2593.000
# Name: totalTFIDFscore, dtype: float64

# %%
product_features_df= review_with_totalReviewCount.pivot_table(index='MeSH Symptom Term',columns='MeSH Disease Term',values='TFIDF score').fillna(0)
product_features_df.head()
# Out:
# MeSH Disease Term        22q11 Deletion Syndrome  \
# MeSH Symptom Term
# Abdomen, Acute                             0.000
# Abdominal Pain                             0.000
# Acute Coronary Syndrome                    0.000
# Aerophagy                                  0.000
# Ageusia                                    0.000
#
# MeSH Disease Term        46, XX Disorders of Sex Development  \
# MeSH Symptom Term
# Abdomen, Acute                                         0.000
# Abdominal Pain                                         0.000
# Acute Coronary Syndrome                                0.000
# Aerophagy                                              0.000
# Ageusia                                                0.000
#
# MeSH Disease Term        46, XY Disorders of Sex Development  \
# MeSH Symptom Term
# Abdomen, Acute                                         0.000
# Abdominal Pain                                         0.000
# Acute Coronary Syndrome                                0.000
# Aerophagy                                              0.000
# Ageusia                                                0.000
#
# MeSH Disease Term        ACTH Syndrome, Ectopic  \
# MeSH Symptom Term
# Abdomen, Acute                            0.000
# Abdominal Pain                            0.848
# Acute Coronary Syndrome                   0.000
# Aerophagy                                 0.000
# Ageusia                                   0.000
#
# MeSH Disease Term        ACTH-Secreting Pituitary Adenoma  \
# MeSH Symptom Term
# Abdomen, Acute                                      0.000
# Abdominal Pain                                      0.000
# Acute Coronary Syndrome                             0.000
# Aerophagy                                           0.000
# Ageusia                                             0.000
#
# MeSH Disease Term        AIDS Arteritis, Central Nervous System  \
# MeSH Symptom Term
# Abdomen, Acute                                            0.000
# Abdominal Pain                                            0.000
# Acute Coronary Syndrome                                   0.000
# Aerophagy                                                 0.000
# Ageusia                                                   0.000
#
# MeSH Disease Term        AIDS Dementia Complex  AIDS-Associated Nephropathy  \
# MeSH Symptom Term
# Abdomen, Acute                           0.000                        0.000
# Abdominal Pain                           0.000                        0.000
# Acute Coronary Syndrome                  0.000                        0.000
# Aerophagy                                0.000                        0.000
# Ageusia                                  0.000                        0.000
#
# MeSH Disease Term        AIDS-Related Complex  \
# MeSH Symptom Term
# Abdomen, Acute                          0.000
# Abdominal Pain                          0.000
# Acute Coronary Syndrome                 0.000
# Aerophagy                               0.000
# Ageusia                                 0.000
#
# MeSH Disease Term        AIDS-Related Opportunistic Infections  ...  \
# MeSH Symptom Term                                               ...
# Abdomen, Acute                                           7.188  ...
# Abdominal Pain                                          14.424  ...
# Acute Coronary Syndrome                                  0.000  ...
# Aerophagy                                                0.000  ...
# Ageusia                                                  0.000  ...
#
# MeSH Disease Term        Zygomatic Fractures  Zygomycosis  \
# MeSH Symptom Term
# Abdomen, Acute                         0.000        0.000
# Abdominal Pain                         0.000        1.697
# Acute Coronary Syndrome                0.000        0.000
# Aerophagy                              0.000        0.000
# Ageusia                                0.000        0.000
#
# MeSH Disease Term        alpha 1-Antitrypsin Deficiency  alpha-Mannosidosis  \
# MeSH Symptom Term
# Abdomen, Acute                                    0.000               0.000
# Abdominal Pain                                    0.848               0.000
# Acute Coronary Syndrome                           0.000               0.000
# Aerophagy                                         0.000               0.000
# Ageusia                                           0.000               0.000
#
# MeSH Disease Term        alpha-Thalassemia  beta-Mannosidosis  \
# MeSH Symptom Term
# Abdomen, Acute                       0.000              0.000
# Abdominal Pain                       1.697              0.000
# Acute Coronary Syndrome              0.000              0.000
# Aerophagy                            0.000              0.000
# Ageusia                              0.000              0.000
#
# MeSH Disease Term        beta-Thalassemia  von Hippel-Lindau Disease  \
# MeSH Symptom Term
# Abdomen, Acute                      2.875                      0.000
# Abdominal Pain                      2.545                      0.848
# Acute Coronary Syndrome             2.598                      0.000
# Aerophagy                           0.000                      0.000
# Ageusia                             0.000                      0.000
#
# MeSH Disease Term        von Willebrand Disease, Type 2  \
# MeSH Symptom Term
# Abdomen, Acute                                    0.000
# Abdominal Pain                                    0.000
# Acute Coronary Syndrome                           0.000
# Aerophagy                                         0.000
# Ageusia                                           0.000
#
# MeSH Disease Term        von Willebrand Diseases
# MeSH Symptom Term
# Abdomen, Acute                             2.875
# Abdominal Pain                             0.848
# Acute Coronary Syndrome                    0.000
# Aerophagy                                  0.000
# Ageusia                                    0.000
#
# [5 rows x 4219 columns]

# %%
from scipy.sparse import csr_matrix

product_features_df_matrix = csr_matrix(product_features_df.values)

# %%
from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(product_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index = np.random.choice(product_features_df.shape[0])
print(query_index)
distances, indices = model_knn.kneighbors(product_features_df.iloc[query_index,:].values.reshape(1, -1), n_neighbors = 6)
# Out:
# 154

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(product_features_df.index[query_index]))
    else:
        print('{0}: {1},  with distance of {2}:'.format(i, product_features_df.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for Hypercalciuria:
#
# 1: Renal Colic,  with distance of 0.5855605086864419:
# 2: Flank Pain,  with distance of 0.7224051136152105:
# 3: Colic,  with distance of 0.7889499831437368:
# 4: Proteinuria,  with distance of 0.8296214878293613:
# 5: Dysuria,  with distance of 0.8571587275137172:
